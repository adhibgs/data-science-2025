# %% [markdown]
# <a href="https://colab.research.google.com/github/adhibgs/data-science-2025/blob/main/Pertemuan1_Adhi_Bagus_May_Maulana_250401020116.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pertemuan ke-1
#
# *   Nama : Adhi Bagus May Maulana
# *   NIM : 250401020116
# *   Kelas : IF405

# %%
# ================================================
# PERTEMUAN 1: Notebook Pertama Data Science
# ================================================
# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# SEL 2: Variabel dan tipe data dasar
nama = "Adhi Bagus May Maulana" # String
angkatan = 2025                 # Integer
ipk = 3.29                      # Float
aktif = True                    # Boolean
print(f"Nama : {nama}")
print(f"Angkatan: {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")
# SEL 3: List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
 print(f" {i}. {tool}")
# SEL 4: Fungsi sederhana
def perkenalan(nama, prodi, angkatan):
 """Fungsi untuk menampilkan perkenalan mahasiswa."""
 return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."
hasil = perkenalan("Adhi Bagus May Maulana", "Informatika", 2025)
print(hasil)
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!
# Nama : Adhi Bagus May Maulana
# Angkatan: 2025
# IPK : 3.29
# Aktif : True
#
# Tools Data Science yang akan kita pelajari:
#  1. Python
#  2. Google Colab
#  3. Jupyter Notebook
#  4. GitHub
# Hai! Saya Adhi Bagus May Maulana dari Informatika, angkatan 2025.

# %% [markdown]
# KESIMPULAN
#
# Dari praktik diatas merupakan output perkenalan dan penggunaan tools Data Science yang akan dipelajari. baris kode yang dibuat merupakan pemahaman Syntak dasar dan output, TIpe data, struktur data lopping dan Fungsi
